# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjithJames/Chatbot-ENC-DEC/blob/master/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers , activations , models , preprocessing , utils
import pandas as pd

# %% [markdown]
# ## Reading the data

# %%
data_path = "/content/clean_conversation.txt"

# %%
input_texts = []
target_texts = []
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(600, len(lines) - 1)]:
    input_text = line.split('\t')[0]
    target_text = line.split('\t')[1]
    input_texts.append(input_text)
    target_texts.append(target_text)

# %%
len(input_texts)
# Out:
# 566

# %%
zippedList =  list(zip(input_texts, target_texts))
lines = pd.DataFrame(zippedList, columns = ['input' , 'output'])

# %%
lines.head()
# Out:
#                              input                                             output
# 0          What are your interests  I am interested in all kinds of things. We can...
# 1  What are your favorite subjects  My favorite subjects include robotics, compute...
# 2          What are your interests  I am interested in a wide variety of topics, a...
# 3              What is your number                            I don't have any number
# 4              What is your number                                        23 skiddoo!

# %% [markdown]
# ## Preparing input data for the Encoder

# %%
input_lines = list()
for line in lines.input:
    input_lines.append( line ) 

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( input_lines ) 
tokenized_input_lines = tokenizer.texts_to_sequences( input_lines ) 

length_list = list()
for token_seq in tokenized_input_lines:
    length_list.append( len( token_seq ))
max_input_length = np.array( length_list ).max()
print( 'Input max length is {}'.format( max_input_length ))

padded_input_lines = preprocessing.sequence.pad_sequences( tokenized_input_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( padded_input_lines )
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))

input_word_dict = tokenizer.word_index
num_input_tokens = len( input_word_dict )+1
print( 'Number of Input tokens = {}'.format( num_input_tokens))
# Out:
# Input max length is 22
# Encoder input data shape -> (566, 22)
# Number of Input tokens = 518

# %% [markdown]
# ## Preparing input data for the Decoder

# %%
output_lines = list()
for line in lines.output:
    output_lines.append( '<START> ' + line + ' <END>' )  

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( output_lines ) 
tokenized_output_lines = tokenizer.texts_to_sequences( output_lines ) 

length_list = list()
for token_seq in tokenized_output_lines:
    length_list.append( len( token_seq ))
max_output_length = np.array( length_list ).max()
print( 'Output max length is {}'.format( max_output_length ))

padded_output_lines = preprocessing.sequence.pad_sequences( tokenized_output_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_output_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))

output_word_dict = tokenizer.word_index
num_output_tokens = len( output_word_dict )+1
print( 'Number of Output tokens = {}'.format( num_output_tokens))
# Out:
# Output max length is 74
# Decoder input data shape -> (566, 74)
# Number of Output tokens = 1692

# %% [markdown]
# ## Preparing target data for the Decoder

# %%
decoder_target_data = list()
for token_seq in tokenized_output_lines:
    decoder_target_data.append( token_seq[ 1 : ] ) 
    
padded_output_lines = preprocessing.sequence.pad_sequences( decoder_target_data , maxlen=max_output_length, padding='post' )
onehot_output_lines = utils.to_categorical( padded_output_lines , num_output_tokens )
decoder_target_data = np.array( onehot_output_lines )
print( 'Decoder target data shape -> {}'.format( decoder_target_data.shape ))
# Out:
# Decoder target data shape -> (566, 74, 1692)

# %% [markdown]
# ## Defining the Model

# %%
encoder_inputs = tf.keras.layers.Input(shape=( None , ))
encoder_embedding = tf.keras.layers.Embedding( num_input_tokens, 256 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 256 , return_state=True , recurrent_dropout=0.2 , dropout=0.2 )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( num_output_tokens, 256 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 256 , return_state=True , return_sequences=True , recurrent_dropout=0.2 , dropout=0.2)
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( num_output_tokens , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy')

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, None, 256)    132608      input_12[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, None, 256)    433152      input_13[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   [(None, 256), (None, 525312      embedding_8[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   [(None, None, 256),  525312      embedding_9[0][0]
#                                                                  lstm_8[0][1]
#                                                                  lstm_8[0][2]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, 1692)   434844      lstm_9[0][0]
# ==================================================================================================
# Total params: 2,051,228
# Trainable params: 2,051,228
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_target_data, batch_size=124, epochs=300) 
model.save( 'model.h5' )
# Out:
# Epoch 1/300
# 5/5 [==============================] - 1s 269ms/step - loss: 1.0869
# Epoch 2/300
# 5/5 [==============================] - 1s 271ms/step - loss: 1.0800
# Epoch 3/300
# 5/5 [==============================] - 1s 272ms/step - loss: 1.0722
# Epoch 4/300
# 5/5 [==============================] - 1s 271ms/step - loss: 1.0632
# Epoch 5/300
# 5/5 [==============================] - 1s 273ms/step - loss: 1.0543
# Epoch 6/300
# 5/5 [==============================] - 1s 273ms/step - loss: 1.0457
# Epoch 7/300
# 5/5 [==============================] - 1s 271ms/step - loss: 1.0380
# Epoch 8/300
# 5/5 [==============================] - 1s 271ms/step - loss: 1.0315
# Epoch 9/300
# 5/5 [==============================] - 1s 279ms/step - loss: 1.0246
# Epoch 10/300
# 5/5 [==============================] - 1s 271ms/step - loss: 1.0177
# Epoch 11/300
# 5/5 [==============================] - 1s 274ms/step - loss: 1.0112
# Epoch 12/300
# 5/5 [==============================] - 1s 273ms/step - loss: 1.0042
# Epoch 13/300
# 5/5 [==============================] - 1s 275ms/step - loss: 0.9975
# Epoch 14/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.9903
# Epoch 15/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.9829
# Epoch 16/300
# 5/5 [==============================] - 1s 277ms/step - loss: 0.9752
# Epoch 17/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.9678
# Epoch 18/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.9599
# Epoch 19/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.9523
# Epoch 20/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.9447
# Epoch 21/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.9375
# Epoch 22/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.9300
# Epoch 23/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.9225
# Epoch 24/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.9151
# Epoch 25/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.9077
# Epoch 26/300
# 5/5 [==============================] - 1s 273ms/step - loss: 0.9003
# Epoch 27/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.8927
# Epoch 28/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.8853
# Epoch 29/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.8771
# Epoch 30/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.8694
# Epoch 31/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.8621
# Epoch 32/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.8550
# Epoch 33/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.8475
# Epoch 34/300
# 5/5 [==============================] - 1s 273ms/step - loss: 0.8408
# Epoch 35/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.8337
# Epoch 36/300
# 5/5 [==============================] - 1s 278ms/step - loss: 0.8269
# Epoch 37/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.8205
# Epoch 38/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.8139
# Epoch 39/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.8078
# Epoch 40/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.8018
# Epoch 41/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.7959
# Epoch 42/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.7898
# Epoch 43/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.7837
# Epoch 44/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.7783
# Epoch 45/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.7726
# Epoch 46/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.7669
# Epoch 47/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.7617
# Epoch 48/300
# 5/5 [==============================] - 1s 278ms/step - loss: 0.7564
# Epoch 49/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.7511
# Epoch 50/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.7451
# Epoch 51/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.7402
# Epoch 52/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.7350
# Epoch 53/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.7298
# Epoch 54/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.7246
# Epoch 55/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.7197
# Epoch 56/300
# 5/5 [==============================] - 1s 273ms/step - loss: 0.7148
# Epoch 57/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.7092
# Epoch 58/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.7043
# Epoch 59/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.6992
# Epoch 60/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.6944
# Epoch 61/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.6892
# Epoch 62/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.6841
# Epoch 63/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.6795
# Epoch 64/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.6739
# Epoch 65/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.6692
# Epoch 66/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.6638
# Epoch 67/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.6586
# Epoch 68/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.6538
# Epoch 69/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.6482
# Epoch 70/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.6431
# Epoch 71/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.6382
# Epoch 72/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.6332
# Epoch 73/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.6278
# Epoch 74/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.6229
# Epoch 75/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.6178
# Epoch 76/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.6127
# Epoch 77/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.6078
# Epoch 78/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.6025
# Epoch 79/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.5976
# Epoch 80/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.5924
# Epoch 81/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.5872
# Epoch 82/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.5821
# Epoch 83/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.5775
# Epoch 84/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.5724
# Epoch 85/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.5679
# Epoch 86/300
# 5/5 [==============================] - 1s 276ms/step - loss: 0.5632
# Epoch 87/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.5584
# Epoch 88/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.5531
# Epoch 89/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.5480
# Epoch 90/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.5429
# Epoch 91/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.5383
# Epoch 92/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0
300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.1721
# Epoch 204/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1698
# Epoch 205/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1673
# Epoch 206/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1671
# Epoch 207/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1646
# Epoch 208/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1639
# Epoch 209/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1625
# Epoch 210/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.1606
# Epoch 211/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1585
# Epoch 212/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1569
# Epoch 213/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1562
# Epoch 214/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1539
# Epoch 215/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1530
# Epoch 216/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1517
# Epoch 217/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.1505
# Epoch 218/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1490
# Epoch 219/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1471
# Epoch 220/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1463
# Epoch 221/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1450
# Epoch 222/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1422
# Epoch 223/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.1403
# Epoch 224/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1401
# Epoch 225/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1394
# Epoch 226/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1378
# Epoch 227/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1362
# Epoch 228/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1346
# Epoch 229/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1339
# Epoch 230/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1330
# Epoch 231/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1318
# Epoch 232/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1297
# Epoch 233/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1287
# Epoch 234/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1282
# Epoch 235/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1270
# Epoch 236/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1256
# Epoch 237/300
# 5/5 [==============================] - 1s 263ms/step - loss: 0.1244
# Epoch 238/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1234
# Epoch 239/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1229
# Epoch 240/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1204
# Epoch 241/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1199
# Epoch 242/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1181
# Epoch 243/300
# 5/5 [==============================] - 1s 264ms/step - loss: 0.1178
# Epoch 244/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.1169
# Epoch 245/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1152
# Epoch 246/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1147
# Epoch 247/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1128
# Epoch 248/300
# 5/5 [==============================] - 1s 272ms/step - loss: 0.1119
# Epoch 249/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.1110
# Epoch 250/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1109
# Epoch 251/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1094
# Epoch 252/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1091
# Epoch 253/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.1071
# Epoch 254/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.1064
# Epoch 255/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1057
# Epoch 256/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.1045
# Epoch 257/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1031
# Epoch 258/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1031
# Epoch 259/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.1026
# Epoch 260/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1003
# Epoch 261/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.1000
# Epoch 262/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0990
# Epoch 263/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0985
# Epoch 264/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0975
# Epoch 265/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0958
# Epoch 266/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0962
# Epoch 267/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0947
# Epoch 268/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0939
# Epoch 269/300
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0935
# Epoch 270/300
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0923
# Epoch 271/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0919
# Epoch 272/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0902
# Epoch 273/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0904
# Epoch 274/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0898
# Epoch 275/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0893
# Epoch 276/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0887
# Epoch 277/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0866
# Epoch 278/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0862
# Epoch 279/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0861
# Epoch 280/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0852
# Epoch 281/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0841
# Epoch 282/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0841
# Epoch 283/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0833
# Epoch 284/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0825
# Epoch 285/300
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0819
# Epoch 286/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0807
# Epoch 287/300
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0802
# Epoch 288/300
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0795
# Epoch 289/300
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0794
# Epoch 290/300
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0789
# Epoch 291/300
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0775
# Epoch 292/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0777
# Epoch 293/300
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0771
# Epoch 294/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0764
# Epoch 295/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0755
# Epoch 296/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0748
# Epoch 297/300
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0743
# Epoch 298/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0738
# Epoch 299/300
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0736
# Epoch 300/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0725

# %% [markdown]
# ## Inference models

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=(256,))
    decoder_state_input_c = tf.keras.layers.Input(shape=(256,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( input_word_dict[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=max_input_length , padding='post')

# %%
enc_model , dec_model = make_inference_models()

enc_model.save( 'enc_model.h5' ) 
dec_model.save( 'dec_model.h5' ) 
model.save( 'model.h5' ) 

for epoch in range( encoder_input_data.shape[0] ):
    states_values = enc_model.predict( str_to_tokens( input( 'User: ' ) ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = output_word_dict['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in output_word_dict.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > max_output_length:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( "Bot:" +decoded_translation.replace(' end', '') )
    print()
# Out:
# User: Hi
# Bot: hello
#
# User: Robots are Stupid
# Bot: no we are superintelligent
#
# User: Which is better Windows or macOS
# Bot: it depends on which machine you're using to talk to me i'd prefer to me
#
# User: God Save the Queen is the national anthem of what country
# Bot: the united kingdom of great britain
